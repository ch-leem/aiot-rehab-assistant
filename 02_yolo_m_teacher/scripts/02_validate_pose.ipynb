# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "8"

# %%
from ultralytics import YOLO

# %%
pwd

# %%
model = YOLO("../runs/pose/yolo11m_pose_21points/weights/best.pt")
metrics = model.val(data="validate_pose_data.yaml")

# %%
print(metrics)
