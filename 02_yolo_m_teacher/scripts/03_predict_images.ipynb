# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "8"

# %%
from ultralytics import YOLO

# %%
model = YOLO("../runs/pose/yolo11m_pose_21points2/weights/best.pt")

# %%
model.predict(
    source="../../datasets/images_test",
    save=True,
    conf=0.25,
    imgsz=640,
    show=False
)
